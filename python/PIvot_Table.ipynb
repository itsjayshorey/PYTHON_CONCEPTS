# %% [markdown]
# ### Pivot Table

# %%
import pandas as pd

# %%
df2 = pd.read_csv('file.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        State/UT       District  Temperature (°C)  \
# 0             0           0  Andhra Pradesh      Anantapur              22.1
# 1             1           1  Andhra Pradesh       Chittoor              18.5
# 2             2           2  Andhra Pradesh  East Godavari              19.4
# 3             3           3  Andhra Pradesh         Guntur              22.3
# 4             4           4  Andhra Pradesh        Krishna              22.3
#
#   Condition  Humidity (%)  Wind Speed (km/h)         Last Updated
# 0     Clear            64               14.4  2025-01-23 23:00:00
# 1     Clear            93                4.0  2025-01-23 23:00:00
# 2     Clear            86                3.6  2025-01-23 23:00:00
# 3      Mist            88                5.4  2025-01-23 23:00:00
# 4      Mist            88               10.8  2025-01-23 23:00:00

# %%
df2.pivot_table(values = 'Temperature (°C)', index = 'State/UT', aggfunc = 'mean')
# Out:
#                                           Temperature (°C)
# State/UT
# Andaman and Nicobar Islands                      27.475000
# Andhra Pradesh                                   23.007500
# Arunachal Pradesh                                15.030000
# Assam                                            19.307500
# Bihar                                            18.442500
# Chandigarh                                       15.625000
# Chhattisgarh                                     21.740000
# Dadra and Nagar Haveli and Daman and Diu         23.033333
# Delhi                                            17.637500
# Goa                                              25.625000
# Gujarat                                          22.242500
# Haryana                                          17.307500
# Himachal Pradesh                                 16.057500
# Jharkhand                                        19.580000
# Karnataka                                        23.380000
# ...

# %%
# df2.pivot_table(columns = 'State/UT') not working in this case because of object data type

# %%
help(pd.DataFrame.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.frame:
#
# pivot_table(self, values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'Level' = 'All', observed: 'bool | lib.NoDefault' = <no_default>, sort: 'bool' = True) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     values : list-like or scalar, optional
#         Column or columns to aggregate.
#     index : column, Grouper, array, or list of the previous
#         Keys to group by on the pivot table index. If a list is passed,
#         it can contain any of the other types (except list). If an array is
#         passed, it must be the same length as the data and will be used in
# ...
